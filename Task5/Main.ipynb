# %%
from MathMethod import *
from numpy import linspace, exp, sqrt
from math import pi
import plotly.express as px

# %% [markdown]
# # Задание 1: Система нелинейных уравнений

# %%
def f1(x, y, z):
    return x**2 + y**2 + z**2 - 1

def f2(x, y, z):
    return 2 * x**2 + y**2 - 4 * z

def f3(x, y, z):
    return 3 * x**2 - 4 * y + z**2

def jacobian(x, y, z):
    return [
        [2 * x, 2 * y, 2 * z],
        [4 * x, 2 * y, -4],
        [6 * x, -4, 2 * z]
    ]

x0, y0, z0 = 1, 1, 1
res, iters = NewtonSystem(jacobian, [f1, f2, f3], [x0, y0, z0], maxIter=30, epsilon=1e-8)
xr, yr, zr = res

print("Система:")
print("x**2 + y**2 + z**2 = 1")
print("2x**2 + y**2 - 4z = 0")
print("3x**2 - 4y + z**2 = 0")
print(f"Начальное приближение: ({x0}, {y0}, {z0})")

print(f"Решение системы: ({xr}, {yr}, {zr})")
print(f"Количество итераций: {iters}")
print("Значение при подстановке в систему:")
print(f"x**2 + y**2 + z**2 = {f1(xr, yr, zr) + 1}")
print(f"2x**2 + y**2 - 4z = {f2(xr, yr, zr)}")
print(f"3x**2 - 4y + z**2 = {f3(xr, yr, zr)}")
# Out:
# Система:
# x**2 + y**2 + z**2 = 1
# 2x**2 + y**2 - 4z = 0
# 3x**2 - 4y + z**2 = 0
# Начальное приближение: (1, 1, 1)
# Решение системы: (0.7851969330623553, 0.4966113929446564, 0.36992283074587234)
# Количество итераций: 6
# Значение при подстановке в систему:
# x**2 + y**2 + z**2 = 1.0
# 2x**2 + y**2 - 4z = 2.220446049250313e-16
# 3x**2 - 4y + z**2 = 0.0

# %%
x0, y0, z0 = 59, 105, 68
res, iters = NewtonSystem(jacobian, [f1, f2, f3], [x0, y0, z0], maxIter=30, epsilon=1e-8)
xr, yr, zr = res

print("Система:")
print("x**2 + y**2 + z**2 = 1")
print("2x**2 + y**2 - 4z = 0")
print("3x**2 - 4y + z**2 = 0")
print(f"Начальное приближение: ({x0}, {y0}, {z0})")

print(f"Решение системы: ({xr}, {yr}, {zr})")
print(f"Количество итераций: {iters}")
print("Значение при подстановке в систему:")
print(f"x**2 + y**2 + z**2 = {f1(xr, yr, zr) + 1}")
print(f"2x**2 + y**2 - 4z = {f2(xr, yr, zr)}")
print(f"3x**2 - 4y + z**2 = {f3(xr, yr, zr)}")
# Out:
# Система:
# x**2 + y**2 + z**2 = 1
# 2x**2 + y**2 - 4z = 0
# 3x**2 - 4y + z**2 = 0
# Начальное приближение: (59, 105, 68)
# Решение системы: (0.7851969330623552, 0.4966113929446564, 0.36992283074587234)
# Количество итераций: 12
# Значение при подстановке в систему:
# x**2 + y**2 + z**2 = 0.9999999999999999
# 2x**2 + y**2 - 4z = 0.0
# 3x**2 - 4y + z**2 = -2.220446049250313e-16

# %%
x0, y0, z0 = -256, 981, 245
res, iters = NewtonSystem(jacobian, [f1, f2, f3], [x0, y0, z0], maxIter=30, epsilon=1e-8)
xr, yr, zr = res

print("Система:")
print("x**2 + y**2 + z**2 = 1")
print("2x**2 + y**2 - 4z = 0")
print("3x**2 - 4y + z**2 = 0")
print(f"Начальное приближение: ({x0}, {y0}, {z0})")

print(f"Решение системы: ({xr}, {yr}, {zr})")
print(f"Количество итераций: {iters}")
print("Значение при подстановке в систему:")
print(f"x**2 + y**2 + z**2 = {f1(xr, yr, zr) + 1}")
print(f"2x**2 + y**2 - 4z = {f2(xr, yr, zr)}")
print(f"3x**2 - 4y + z**2 = {f3(xr, yr, zr)}")
# Out:
# Система:
# x**2 + y**2 + z**2 = 1
# 2x**2 + y**2 - 4z = 0
# 3x**2 - 4y + z**2 = 0
# Начальное приближение: (-256, 981, 245)
# Решение системы: (-0.7851969330623552, 0.4966113929446564, 0.3699228307458724)
# Количество итераций: 15
# Значение при подстановке в систему:
# x**2 + y**2 + z**2 = 1.0
# 2x**2 + y**2 - 4z = -2.220446049250313e-16
# 3x**2 - 4y + z**2 = -1.6653345369377348e-16

# %% [markdown]
# # Задание 2: Найти корень функции по значению

# %%
def Laplas(x, integralCount=10, integralMethod=SympsonIntegral):
    def underIntegral(x):
        return exp(-x ** 2 / 2)
    intx = linspace(0, x, integralCount)
    return 2 / sqrt(2 * pi) * integralMethod(intx, underIntegral)


x = linspace(-5, 5, 100)
y = [Laplas(i) for i in x]

y_pred = linspace(-0.999999, 0.999999, 50)
x_pred = [HalfDivision(Laplas, y, min(x), max(x), maxIter=30, epsilon=1e-8)[0] for y in y_pred]

# print(y_pred)
# print(x_pred)
fig = px.line(x=x, y=y)


fig.add_scatter(x=x_pred, y=y_pred, mode='lines+markers', name='HalfDivision')


fig.show()

# %% [markdown]
# # Задание 3: Решение краевой задачи

# %%
# Краевые условия
x0 = 0
y0 = 1
x1 = 1
y1 = 3

# Количество отрезков и шаг по x
N = 100
step = (x1 - x0) / (N)

# Массив x
x = linspace(x0, x1, N + 1)

# Функция генераци якобиана для уравнения y'' - y^3 = x^2, при замене второй производной по разностной схеме для всех точек x
# y - Массив текущих приближённых значений 
def jacobian(*y):
    N = len(y)
    res = []
    res.append([1] + [0] * (N - 1))
    for i in range(1, N - 1):
        res.append([0] * (i - 1) + [1 / step**2] + [-2/step**2 - 3 * y[i]**2]  + [1/step**2] + [0] * (N - i - 2))
    res.append([0] * (N - 1) + [1])
    return res

# Функция для генерации n - ой функции в системе нелинейных уравнений при разложении по разностной схеме.
def f(n):
    if n == 0:
        def resf(*y):
            return y[0] - y0
    elif n == N:
        def resf(*y):
            return y[n] - y1
    else:
        def resf(*y):
            return (y[n - 1] + -2 * y[n] + y[n + 1]) / step**2 - y[n]**3 - x[n]**2
    return resf

funcs = [f(i) for i in range(N + 1)]

def starty(x):
    return 2 * x + 1 # Удовлетворяет краевым условиям

y = [starty(xp) for xp in x]

res, iters = NewtonSystem(jacobian, funcs, y, maxIter=30, epsilon=1e-15)
print("Число итераций: {iters}")
fig = px.line(x=x, y=res)

fig.show()
# Out:
# 7
